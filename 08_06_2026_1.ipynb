# %%
# !pip install groq gtts
from groq import Groq
from gtts import gTTS
import os

# Initialize Groq client
client = Groq(
    api_key="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"
)

user_prompt = input("Ask AI: ")

# Generate response
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": user_prompt}
    ]
)

answer = response.choices[0].message.content

print("\nAI Response:\n")
print(answer)

# Convert response to speech
tts = gTTS(text=answer, lang="en")

tts.save("groq_response.mp3")

print("\nSpeech saved as groq_response.mp3")
# Out:
# ...
# Ask AI: hlo
#
# AI Response:
#
# Hello. How can I assist you today?
#
# Speech saved as groq_response.mp3

# %%
from groq import Groq
from gtts import gTTS
import os

# Initialize Groq client
client = Groq(
    api_key="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"
)

# Generate text
user_prompt = "Welcome to the Artificial Intelligence laboratory session."
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": user_prompt}]
)

answer = response.choices[0].message.content
print("AI Response:", answer)

# Convert text to speech using gTTS
tts = gTTS(text=answer, lang="en")
tts.save("output.mp3")

print("Audio saved as output.mp3")
# Out:
# AI Response: Welcome to the Artificial Intelligence laboratory session. I'm excited to be a part of this experience and explore the vast possibilities of AI with you. What topics or projects would you like to cover during this session? We could dive into machine learning, natural language processing, computer vision, or any other area of interest. Let me know, and I'll do my best to assist you.
# Audio saved as output.mp3

# %%
from groq import Groq
import os

# Initialize Groq client
client = Groq(api_key="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")

# Prompt
prompt = "Explain malware analysis in 100 words."

# Generate response
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",  # Groq's large LLM
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# Extract text from the response
answer = response.choices[0].message.content

print("Groq Response:\n")
print(answer)
# Out:
# Groq Response:
#
# Malware analysis is the process of examining malicious software to understand its behavior, capabilities, and intentions. It involves static and dynamic analysis techniques to dissect the malware's code, identify potential vulnerabilities, and determine its impact on a system. Analysts use various tools and methods, such as sandboxing and reverse engineering, to analyze the malware's interactions with the system, network, and other software, helping to develop effective detection and mitigation strategies to prevent future attacks. This helps organizations strengthen their cybersecurity defenses and protect against emerging threats. Analysis results inform incident response and threat intelligence efforts.

# %%
# !pip install groq diffusers transformers accelerate
from groq import Groq
from diffusers import StableDiffusionPipeline
import torch
from PIL import Image

# Initialize Groq client
client = Groq(api_key="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")

# Original text prompt
prompt = """
Create a futuristic AI laboratory with
students learning machine learning,
holographic displays, realistic style.
"""

# Optional: refine prompt with Groq
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": f"Refine this prompt for text-to-image generation:\n{prompt}"}]
)

refined_prompt = response.choices[0].message.content
print("Refined prompt:", refined_prompt)

# Determine device to use
device = "cuda" if torch.cuda.is_available() else "cpu"

# Generate image using Stable Diffusion
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16 if device == "cuda" else torch.float32 # Use float32 for CPU
).to(device)

image: Image.Image = pipe(refined_prompt).images[0]

# Save image
image.save("generated_image_groq.png")
print("Saved generated_image_groq.png")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.2 MB/s eta 0:00:00
# ...
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Refined prompt: Here's a refined prompt for text-to-image generation:
#
# ...

# %%
from PIL import Image

# Load and display the generated image
image_path = "generated_image_groq.png"
img = Image.open(image_path)
display(img)
print(f"Displayed {image_path}")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
# Displayed generated_image_groq.png

# %%
from openai import OpenAI
import os

# Initialize client
client = OpenAI(api_key="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")

# Generate response
response = client.chat.completions.create(
    model="gpt-4o",  # Tweak model if needed
    messages=[
        {"role": "user", "content": "Explain malware analysis in 100 words."}
    ]
)

# Print the generated text
answer = response.choices[0].message.content
print("AI Response:\n")
print(answer)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_5312/1543679435.py in <cell line: 0>()
#       6
#       7 # Generate response
# ----> 8 response = client.chat.completions.create(
#       9     model="gpt-4o",  # Tweak model if needed
#      10     messages=[
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     296                         msg = f"Missing required argument: {quote(missing[0])}"
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#     300         return wrapper  # type: ignore
#
# ...

# %%
import os
from openai import OpenAI

# Initialize OpenAI client
client = OpenAI(api_key="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")

# The text you want to convert to speech
text_to_speak = "Welcome to the Artificial Intelligence laboratory session."

# Generate speech using OpenAI TTS
response = client.audio.speech.create(
    model="gpt-4o-mini-tts",  # TTS-capable model
    voice="alloy",            # You can choose voices like "alloy", "aria", etc.
    input=text_to_speak
)

# Save audio to file
response.stream_to_file("output.wav")

print("Audio saved as output.wav")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_5312/1881507015.py in <cell line: 0>()
#       9
#      10 # Generate speech using OpenAI TTS
# ---> 11 response = client.audio.speech.create(
#      12     model="gpt-4o-mini-tts",  # TTS-capable model
#      13     voice="alloy",            # You can choose voices like "alloy", "aria", etc.
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/audio/speech.py in create(self, input, model, voice, instructions, response_format, speed, stream_format, extra_headers, extra_query, extra_body, timeout)
#     105         """
#     106         extra_headers = {"Accept": "application/octet-stream", **(extra_headers or {})}
# --> 107         return self._post(
#     108             "/audio/speech",
#     109             body=maybe_transform(
#
# ...

# %%
import time
import psutil
import torch
from transformers import (
    AutoTokenizer,
    AutoModel,
    AutoModelForCausalLM
)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

TEST_TEXT = """
Machine learning techniques are increasingly used for phishing detection.
Transformers provide strong contextual understanding.
"""

# -------------------------
# Load Models
# -------------------------

bert_model_name = "bert-base-uncased"
gpt_model_name = "gpt2"

print("Loading Models...")

bert_tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
bert_model = AutoModel.from_pretrained(
    bert_model_name
).to(DEVICE)

gpt_tokenizer = AutoTokenizer.from_pretrained(gpt_model_name)

if gpt_tokenizer.pad_token is None:
    gpt_tokenizer.pad_token = gpt_tokenizer.eos_token

gpt_model = AutoModelForCausalLM.from_pretrained(
    gpt_model_name
).to(DEVICE)

# -------------------------
# Benchmark Function
# -------------------------

def benchmark(model, tokenizer, text, model_type):

    process = psutil.Process()

    memory_before = process.memory_info().rss / 1024**2

    tokens = tokenizer(
        text,
        return_tensors="pt",
        padding=True,
        truncation=True
    )

    tokens = {k:v.to(DEVICE) for k,v in tokens.items()}

    start = time.time()

    with torch.no_grad():

        if model_type == "BERT":
            output = model(**tokens)

        else:
            output = model.generate(
                tokens["input_ids"],
                max_new_tokens=50
            )

    end = time.time()

    memory_after = process.memory_info().rss / 1024**2

    total_tokens = tokens["input_ids"].shape[1]

    return {
        "Latency(sec)": round(end-start,4),
        "Tokens": total_tokens,
        "Memory(MB)": round(
            memory_after-memory_before,
            2
        ),
        "Tokens/sec":
            round(total_tokens/(end-start),2)
    }

# -------------------------
# Run Benchmarks
# -------------------------

bert_results = benchmark(
    bert_model,
    bert_tokenizer,
    TEST_TEXT,
    "BERT"
)

gpt_results = benchmark(
    gpt_model,
    gpt_tokenizer,
    TEST_TEXT,
    "GPT"
)

# -------------------------
# Print Results
# -------------------------

print("\n===== Benchmark Results =====")

print("\nBERT")
for k,v in bert_results.items():
    print(k,":",v)

print("\nGPT")
for k,v in gpt_results.items():
    print(k,":",v)

print("\nModel Info")

print("BERT Context Window: 512")
print("GPT2 Context Window: 1024")

print("Device:", DEVICE)
# Out:
# Loading Models...
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Prepare data for plotting
metrics = ['Latency(sec)', 'Tokens', 'Memory(MB)', 'Tokens/sec']

data = {
    'Model': ['BERT'] * len(metrics) + ['GPT'] * len(metrics),
    'Metric': metrics * 2,
    'Value': [
        bert_results['Latency(sec)'], bert_results['Tokens'], bert_results['Memory(MB)'], bert_results['Tokens/sec'],
        gpt_results['Latency(sec)'], gpt_results['Tokens'], gpt_results['Memory(MB)'], gpt_results['Tokens/sec']
    ]
}

df_results = pd.DataFrame(data)

# Create subplots for each metric
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for i, metric in enumerate(metrics):
    sns.barplot(x='Model', y='Value', data=df_results[df_results['Metric'] == metric], ax=axes[i], palette='viridis')
    axes[i].set_title(f'{metric} Comparison')
    axes[i].set_ylabel(metric)
    axes[i].set_xlabel('')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_5312/1894652852.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Value', data=df_results[df_results['Metric'] == metric], ax=axes[i], palette='viridis')
# /tmp/ipykernel_5312/1894652852.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Value', data=df_results[df_results['Metric'] == metric], ax=axes[i], palette='viridis')
# /tmp/ipykernel_5312/1894652852.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot of Latency vs. Memory
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='Latency(sec)',
    y='Memory(MB)',
    hue='Model',
    data=df_results[df_results['Metric'].isin(['Latency(sec)', 'Memory(MB)'])].pivot(index='Model', columns='Metric', values='Value').reset_index(),
    s=200, # size of the points
    palette='viridis'
)

# Annotate points with model names
for i, row in df_results[df_results['Metric'].isin(['Latency(sec)', 'Memory(MB)'])].pivot(index='Model', columns='Metric', values='Value').reset_index().iterrows():
    plt.annotate(row['Model'], (row['Latency(sec)'], row['Memory(MB)']), textcoords="offset points", xytext=(0,10), ha='center')

plt.title('Latency vs. Memory Usage for BERT and GPT')
plt.xlabel('Latency (seconds)')
plt.ylabel('Memory Usage (MB)')
plt.grid(True)
plt.legend(title='Model')
plt.show()

# %%
import os
import time
import psutil
import pandas as pd

from openai import OpenAI
from google import genai

# -----------------------------
# API Clients
# -----------------------------

openai_client = OpenAI(
    api_key=("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")
)

gemini_client = genai.Client(
    api_key=("AIzaSyCklcB00WqbtMUGFMVhoNym6x2_9b8AN_s")
)

PROMPTS = [
    "Explain phishing attacks",
    "Write python code for bubble sort",
    "Explain transformers in AI"
]

# -----------------------------
# Benchmark Function
# -----------------------------

def benchmark_gpt3(prompt):

    process = psutil.Process()

    mem_before = process.memory_info().rss / 1024**2

    start = time.time()

    response = openai_client.completions.create(
        model="davinci-002",
        prompt=prompt,
        max_tokens=150
    )

    end = time.time()

    mem_after = process.memory_info().rss / 1024**2

    output = response.choices[0].text

    return {
        "model":"GPT-3",
        "latency_sec":round(end-start,3),
        "memory_mb":round(
            mem_after-mem_before,
            2
        ),
        "output_chars":len(output),
        "response":output[:150]
    }


def benchmark_gemini(prompt):

    process = psutil.Process()

    mem_before = process.memory_info().rss / 1024**2

    start = time.time()

    response = gemini_client.models.generate_content(
        model="gemini-2.0-flash",
        contents=prompt
    )

    end = time.time()

    mem_after = process.memory_info().rss / 1024**2

    output = response.text

    return {
        "model":"Gemini-2",
        "latency_sec":round(end-start,3),
        "memory_mb":round(
            mem_after-mem_before,
            2
        ),
        "output_chars":len(output),
        "response":output[:150]
    }

# -----------------------------
# Execute Tests
# -----------------------------

results = []

for p in PROMPTS:

    print("\nTesting:", p)

    results.append(
        benchmark_gpt3(p)
    )

    results.append(
        benchmark_gemini(p)
    )

df = pd.DataFrame(results)

print("\n========== RESULTS ==========\n")

print(df)

df.to_csv(
    "benchmark_results.csv",
    index=False
)

print(
    "\nSaved benchmark_results.csv"
)
# Out:
# Testing: Explain phishing attacks
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_5312/2845223416.py in <cell line: 0>()
#     102
#     103     results.append(
# --> 104         benchmark_gpt3(p)
#     105     )
#     106
#
# /tmp/ipykernel_5312/2845223416.py in benchmark_gpt3(prompt)
#      37     start = time.time()
#      38
# ---> 39     response = openai_client.completions.create(
#      40         model="davinci-002",
#      41         prompt=prompt,
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     296                         msg = f"Missing required argument: {quote(missing[0])}"
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#     300         return wrapper  # type: ignore
#
# ...
